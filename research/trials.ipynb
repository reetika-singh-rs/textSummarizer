# %%
d = {"key": "value", "key1":"value1"}

# %%
d['key1']
# Out:
# 'value1'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "value", "key1":"value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from ensure import ensure_annotations
#
# File c:\Users\surit\OneDrive\Documents\Power BI Desktop\Custom Connectors\envs\textS\Lib\site-packages\ensure\__init__.py:3
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       2 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 3 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_assertRaisesRegex, ensure_annotations
#       5 # Your code here
#
# ImportError: cannot import name 'ensure_assertRaisesRegex' from 'ensure.main' (c:\Users\surit\OneDrive\Documents\Power BI Desktop\Custom Connectors\envs\textS\Lib\site-packages\ensure\main.py)

# %%
from ensure import ensure_annotations
# Out:
# ---------------------------------------------------------------------------
#
# ImportError                               Traceback (most recent call last)
#
# Cell In[29], line 1
#
# ----> 1 from ensure import ensure_annotations
#
#
#
# File c:\Users\surit\OneDrive\Documents\Power BI Desktop\Custom Connectors\envs\textS\Lib\site-packages\ensure\__init__.py:3
#
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#
#       2 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
#
# ----> 3 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_assertRaisesRegex, ensure_annotations
#
#       5 # Your code here
#
#
#
# ImportError: cannot import name 'ensure_assertRaisesRegex' from 'ensure.main' (c:\Users\surit\OneDrive\Documents\Power BI Desktop\Custom Connectors\envs\textS\Lib\site-packages\ensure\main.py)

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x * y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 @ensure_annotations
#       2 def get_product(x:int, y:int) -> int:
#       3     return x * y
#
# NameError: name 'ensure_annotations' is not defined

# %%
import ensure
help(ensure)
# Out:
# Help on package ensure:
#
# NAME
#     ensure
#
# PACKAGE CONTENTS
#     _types
#     main
#
# DATA
#     check = <ensure.main.Check object>
#     ensure = <ensure.main.Ensure object at 0x2298623cb00 inspecting None>
#
# FILE
#     c:\users\surit\onedrive\documents\power bi desktop\custom connectors\envs\texts\lib\site-packages\ensure\__init__.py

# %%
from ensure import main
help(main)
# Out:
# Help on module ensure.main in ensure:
#
# NAME
#     ensure.main
#
# CLASSES
#     builtins.AssertionError(builtins.Exception)
#         EnsureError
#     builtins.object
#         Inspector
#             CallableInspector
#             ChainInspector
#             Ensure
#             IterableInspector
#             KeyInspector
#             MappingInspector
#             MultiInspector
#                 MultiEnsure
#             ReferenceInspector
#         InspectorProxy
#             Check
#             NoOpInspector
#         WrappedFunction
#             WrappedFunctionReturn
#
#     class CallableInspector(Inspector)
#      |  CallableInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      CallableInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __getattr__(self, item)
#      |
#      |  returns(self, value)
#      |      returns is a synonym for equals only for called_with()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class ChainInspector(Inspector)
#      |  ChainInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      ChainInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  also
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class Check(InspectorProxy)
#      |  Check(*args, **kwargs)
#      |
#      |  Like Ensure, but if a check fails, saves the error instead of raising it immediately. The error can then be acted
#      |  upon using :meth:`or_raise()` or :meth:`or_call()`.
#      |
#      |  ``.each_of()`` is not supported by the **Check** inspector; all other methods are supported.
#      |
#      |  Method resolution order:
#      |      Check
#      |      InspectorProxy
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __bool__(self)
#      |
#      |  __nonzero__ = __bool__(self)
#      |
#      |  or_call(self, _callable, *args, **kwargs)
#      |      Calls **_callable** with supplied args and kwargs if a predicate fails.
#      |
#      |  or_raise(self, error_factory, message=None, *args, **kwargs)
#      |      Raises an exception produced by **error_factory** if a predicate fails.
#      |
#      |      :param error_factory:
#      |          Class or callable (e.g. :class:`Exception`) which will be invoked to produce the resulting exception.
#      |          You can define a custom callable here; it will be given the underlying predicate's exception (AssertError)
#      |          as the first argument, followed by any arguments passed to ``or_raise``.
#      |      :param message:
#      |          String to be formatted and passed as the first argument to *error_factory*. If this is given, subsequent
#      |          arguments passed to ``or_raise`` will be used to format contents of the string, and will not be passed to
#      |          ``error_factory``. The keyword argument ``error`` will be set to the underlying predicate's exception.
#      |
#      |  otherwise = or_raise(self, error_factory, message=None, *args, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from InspectorProxy:
#      |
#      |  __call__(self, *args, **kwargs)
#      |      Call self as a function.
#      |
#      |  __getattr__(self, item)
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from InspectorProxy:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class Ensure(Inspector)
#      |  Ensure(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Constructs a root-level inspector, which can perform a variety of checks (*predicates*) on subjects passed to
#      |  it. If the checks do not pass, by default :class:`EnsureError` is raised. This can be configured by passing the
#      |  ``error_factory`` keyword to the constructor.
#      |
#      |  Subjects can be passed to the inspector at construction time or by calling the resulting object (each call resets
#      |  the subject):
#      |
#      |  .. code-block:: python
#      |
#      |      Ensure(1).is_an(int)
#      |
#      |      e = Ensure()
#      |      e(1).is_an(int)
#      |
#      |  Some predicates return child inspectors which can be chained into a series of predicates, for example:
#      |
#      |  .. code-block:: python
#      |
#      |      ensure({1: {2: "a"}}).has_key(1).whose_value.is_a(dict).of(int).to(str)
#      |
#      |  Method resolution order:
#      |      Ensure
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  called_with(self, *args, **kwargs)
#      |      Before evaluating subsequent predicates, calls :attr:`subject` with given arguments (but unlike a direct call,
#      |      catches and transforms any exceptions that arise during the call).
#      |
#      |  contains(self, element)
#      |      Ensures :attr:`subject` contains *other*.
#      |
#      |  contains_all_of(self, elements)
#      |      Ensures :attr:`subject` contains all of *elements*, which must be an iterable.
#      |
#      |  contains_key = has_key(self, key)
#      |
#      |  contains_no(self, prototype)
#      |      Ensures no item of :attr:`subject` is of class *prototype*.
#      |
#      |  contains_none_of(self, elements)
#      |      Ensures :attr:`subject` contains none of *elements*, which must be an iterable.
#      |
#      |  contains_one_of(self, elements)
#      |      Ensures :attr:`subject` contains exactly one of *elements*, which must be an iterable.
#      |
#      |  contains_one_or_more_of = contains_some_of(self, elements)
#      |
#      |  contains_only(self, elements)
#      |      Ensures :attr:`subject` contains all of *elements*, which must be an iterable, and no other items.
#      |
#      |  contains_some_of(self, elements)
#      |      Ensures :attr:`subject` contains at least one of *elements*, which must be an iterable.
#      |
#      |  does_not_contain(self, element)
#      |      Ensures :attr:`subject` does not contain *element*.
#      |
#      |  does_not_equal = is_not_equal_to(self, other)
#      |
#      |  equals(self, other)
#      |      Ensures :attr:`subject` is equal to *other*.
#      |
#      |  exceeds = is_greater_than(self, other)
#      |
#      |  has_attribute(self, attr)
#      |      Ensures :attr:`subject` has an attribute *attr*.
#      |
#      |  has_key(self, key)
#      |      Ensures :attr:`subject` is a :class:`collections.Mapping` and contains *key*.
#      |
#      |  has_keys(self, keys)
#      |      Ensures :attr:`subject` is a :class:`collections.Mapping` and contains *keys*, which must be an iterable.
#      |
#      |  has_length(self, length=None, min=None, max=None)
#      |      Ensures :attr:`subject` has length *length* (if given), length at least *min* (if given), and length at most
#      |      *max* (if given).
#      |
#      |  has_only_keys(self, keys)
#      |      Ensures :attr:`subject` is a :class:`collections.Mapping` and contains *keys*, and no other keys.
#      |
#      |  hasattr = has_attribute(self, attr)
#      |
#      |  is_(self, other)
#      |      Ensures :attr:`subject` is *other* (object identity check).
#      |
#      |  is_a(self, prototype)
#      |      Ensures :attr:`subject` is an object of class *prototype*.
#      |
#      |  is_a_dict_of(self, prototype)
#      |      Ensures :attr:`subject` is a :class:`dict` containing only objects of class *prototype*.
#      |
#      |  is_a_list_of(self, prototype)
#      |      Ensures :attr:`subject` is a :class:`list` containing only objects of class *prototype*.
#      |
#      |  is_a_mapping_of(self, prototype)
#      |      Ensures :attr:`subject` is a :class:`collections.Mapping` containing only objects of class *prototype*.
#      |
#      |  is_a_negative(self, prototype)
#      |      Ensures :attr:`subject` is less than 0 and is an object of class *prototype*.
#      |
#      |  is_a_nonempty(self, prototype)
#      |      Ensures :attr:`subject` is an object of class *prototype* and has non-zero length.
#      |
#      |  is_a_nonnegative(self, prototype)
#      |      Ensures :attr:`subject` is greater than or equal to 0 and is an object of class *prototype*.
#      |
#      |  is_a_numeric_bytestring(self)
#      |
#      |  is_a_numeric_string(self)
#      |
#      |  is_a_positive(self, prototype)
#      |      Ensures :attr:`subject` is greater than 0 and is an object of class *prototype*.
#      |
#      |  is_a_set_of(self, prototype)
#      |      Ensures :attr:`subject` is a :class:`set` containing only objects of class *prototype*.
#      |
#      |  is_an = is_a(self, prototype)
#      |
#      |  is_an_empty(self, prototype)
#      |      Ensures :attr:`subject` is an object of class *prototype* and has zero length.
#      |
#      |  is_an_instance_of = is_a(self, prototype)
#      |
#      |  is_an_integer_bytestring(self)
#      |
#      |  is_an_integer_string(self)
#      |
#      |  is_an_iterable_of(self, prototype)
#      |      Ensures :attr:`subject` is an iterable containing only objects of class *prototype*.
#      |
#      |  is_callable(self)
#      |      Ensures :attr:`subject` is a callable.
#      |
#      |  is_empty(self)
#      |      Ensures :attr:`subject` has length zero.
#      |
#      |  is_false(self)
#      |      Ensures :attr:`subject` is ``False``.
#      |
#      |  is_greater_than(self, other)
#      |      Ensures :attr:`subject` is greater than *other*.
#      |
#      |  is_greater_than_or_equal_to(self, other)
#      |      Ensures :attr:`subject` is greater than or equal to *other*.
#      |
#      |  is_in(self, iterable)
#      |      Ensures :attr:`subject` is contained in *iterable*.
#      |
#      |  is_less_than(self, other)
#      |      Ensures :attr:`subject` is less than *other*.
#      |
#      |  is_less_than_or_equal_to(self, other)
#      |      Ensures :attr:`subject` is less than or equal to *other*.
#      |
#      |  is_negative(self)
#      |      Ensures :attr:`subject` is less than 0.
#      |
#      |  is_none(self)
#      |      Ensures :attr:`subject` is ``None``.
#      |
#      |  is_nonempty(self)
#      |      Ensures :attr:`subject` has non-zero length.
#      |
#      |  is_nonnegative(self)
#      |      Ensures :attr:`subject` is greater than or equal to 0.
#      |
#      |  is_not(self, other)
#      |      Ensures :attr:`subject` is not *other* (object identity check).
#      |
#      |  is_not_a(self, prototype)
#      |      Ensures :attr:`subject` is not an object of class *prototype*.
#      |
#      |  is_not_equal_to(self, other)
#      |      Ensures :attr:`subject` is not equal to *other*.
#      |
#      |  is_not_in(self, iterable)
#      |      Ensures :attr:`subject` is not contained in *iterable*.
#      |
#      |  is_not_none(self)
#      |      Ensures :attr:`subject` is not ``None``.
#      |
#      |  is_numeric(self)
#      |      Ensures :attr:`subject` is an int, float, or long.
#      |
#      |  is_positive(self)
#      |      Ensures :attr:`subject` is greater than 0.
#      |
#      |  is_sorted(self, key=None)
#      |
#      |  is_true(self)
#      |      Ensures :attr:`subject` is ``True``.
#      |
#      |  matches(self, pattern, flags=0)
#      |      Ensures :attr:`subject` matches regular expression *pattern*.
#      |
#      |  not_a = is_not_a(self, prototype)
#      |
#      |  not_in = is_not_in(self, iterable)
#      |
#      |  raises(self, expected_exception)
#      |      Ensures preceding predicates (specifically, :meth:`called_with()`) result in *expected_exception* being raised.
#      |
#      |  raises_regex(self, expected_exception, expected_regexp)
#      |      Ensures preceding predicates (specifically, :meth:`called_with()`) result in *expected_exception* being raised,
#      |      and the string representation of *expected_exception* must match regular expression *expected_regexp*.
#      |
#      |  satisfies(self, predicate, *args, **kwargs)
#      |
#      |  with_args = called_with(self, *args, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods defined here:
#      |
#      |  each_of(iterable)
#      |      Applies subsequent predicate(s) to all items in *iterable*.
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  is_none_or
#      |      Ensures :attr:`subject` is either ``None``, or satisfies subsequent (chained) conditions::
#      |
#      |          Ensure(None).is_none_or.is_an(int)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class EnsureError(builtins.AssertionError)
#      |  Method resolution order:
#      |      EnsureError
#      |      builtins.AssertionError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.AssertionError:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.AssertionError:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.AssertionError
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Inspector(builtins.object)
#      |  Inspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class InspectorProxy(builtins.object)
#      |  InspectorProxy(*args, **kwargs)
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, *args, **kwargs)
#      |      Call self as a function.
#      |
#      |  __getattr__(self, item)
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class IterableInspector(Inspector)
#      |  IterableInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      IterableInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  of(self, prototype)
#      |
#      |  of_nonempty(self, prototype)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class KeyInspector(Inspector)
#      |  KeyInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      KeyInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Readonly properties defined here:
#      |
#      |  whose_value
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class MappingInspector(Inspector)
#      |  MappingInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      MappingInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  to(self, prototype)
#      |
#      |  to_nonempty(self, prototype)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class MultiEnsure(MultiInspector)
#      |  MultiEnsure(iterable, inspector)
#      |
#      |  Maps a single Ensure object to an iterable of subjects.
#      |
#      |  Method resolution order:
#      |      MultiEnsure
#      |      MultiInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, iterable, inspector)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from MultiInspector:
#      |
#      |  __getattr__(self, item)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class MultiInspector(Inspector)
#      |  MultiInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Calls a list of inspector objects on a single subject.
#      |
#      |  Method resolution order:
#      |      MultiInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __getattr__(self, item)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class NoOpInspector(InspectorProxy)
#      |  NoOpInspector(*args, **kwargs)
#      |
#      |  Goes through the motions of Ensure, but never raises on the error condition. For chaining with conditional
#      |  predicates like ``is_none_or``.
#      |
#      |  Method resolution order:
#      |      NoOpInspector
#      |      InspectorProxy
#      |      builtins.object
#      |
#      |  Methods inherited from InspectorProxy:
#      |
#      |  __call__(self, *args, **kwargs)
#      |      Call self as a function.
#      |
#      |  __getattr__(self, item)
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from InspectorProxy:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class ReferenceInspector(Inspector)
#      |  ReferenceInspector(subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |
#      |  Method resolution order:
#      |      ReferenceInspector
#      |      Inspector
#      |      builtins.object
#      |
#      |  Readonly properties defined here:
#      |
#      |  which
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Inspector:
#      |
#      |  __call__(self, subject=None)
#      |      Call self as a function.
#      |
#      |  __init__(self, subject=None, error_factory=<class 'ensure.main.EnsureError'>, catch=<class 'Exception'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Inspector:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class WrappedFunction(builtins.object)
#      |  WrappedFunction(arg_properties, f)
#      |
#      |  Wrapper for functions to check argument annotations
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, *args, **kwargs)
#      |      Call self as a function.
#      |
#      |  __get__(self, obj, type=None)
#      |
#      |  __getattr__(self, attr_name)
#      |
#      |  __init__(self, arg_properties, f)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__(self)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
#     class WrappedFunctionReturn(WrappedFunction)
#      |  WrappedFunctionReturn(arg_properties, f, return_templ)
#      |
#      |  Wrapper for functions to check argument annotations with return checking
#      |
#      |  Method resolution order:
#      |      WrappedFunctionReturn
#      |      WrappedFunction
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, *args, **kwargs)
#      |      Call self as a function.
#      |
#      |  __init__(self, arg_properties, f, return_templ)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from WrappedFunction:
#      |
#      |  __get__(self, obj, type=None)
#      |
#      |  __getattr__(self, attr_name)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__(self)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from WrappedFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#
# FUNCTIONS
#     ensure_annotations(f)
#         Decorator to be used on functions with annotations. Runs type checks to enforce annotations. Raises
#         :class:`EnsureError` if any argument passed to *f* is not of the type specified by the annotation. Also raises
#         :class:`EnsureError` if the return value of *f* is not of the type specified by the annotation. Examples:
#
#         .. code-block:: python
#
#             from ensure import ensure_annotations
#
#             @ensure_annotations
#             def f(x: int, y: float) -> float:
#                 return x+y
#
#             print(f(1, y=2.2))
#
#             >>> 3.2
#
#             print(f(1, y=2))
#
#             >>> ensure.EnsureError: Argument y of type <class 'int'> to
#             <function f at 0x109b7c710> does not match annotation type <class 'float'>
#
#         .. warning::
#
#            The current implementation of the decorator might trigger
#            a ``_pickle.PicklingError`` when a decorated function is run through
#            ``multiprocessing``.
#
# DATA
#     USING_PYTHON2 = False
#     check = <ensure.main.Check object>
#     ensure = <ensure.main.Ensure object at 0x2298623cb00 inspecting None>
#     string_types = (<class 'str'>,)
#     unittest_case = <unittest.case.TestCase testMethod=__init__>
#
# FILE
#     c:\users\surit\onedrive\documents\power bi desktop\custom connectors\envs\texts\lib\site-packages\ensure\main.py

# %%
pip install ensure
# Out:
# Requirement already satisfied: ensure in c:\users\surit\onedrive\documents\power bi desktop\custom connectors\envs\texts\lib\site-packages (1.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\surit\onedrive\documents\power bi desktop\custom connectors\envs\texts\lib\site-packages (from ensure) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure

ensure(1).is_an(int)
ensure({1: {2: 3}}).equals({1: {2: 3}}).also.contains(1)
ensure({1: "a"}).has_key(1).whose_value.has_length(1)
ensure.each_of([{1: 2}, {3: 4}]).is_a(dict).of(int).to(int)
ensure(int).called_with("1100101", base=2).returns(101)
ensure(dict).called_with(1, 2).raises(TypeError)
check(1).is_a(float).or_raise(Exception, "An error happened: {msg}. See http://example.com for more information.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 9
#       7 ensure(int).called_with("1100101", base=2).returns(101)
#       8 ensure(dict).called_with(1, 2).raises(TypeError)
# ----> 9 check(1).is_a(float).or_raise(Exception, "An error happened: {msg}. See http://example.com for more information.")
#
# NameError: name 'check' is not defined

# %%
from ensure import ensure_annotations

@ensure_annotations
def f(x: int, y: float) -> float:
    return x+y

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 get_product(x = 2, y = "4")
#
# File c:\Users\surit\OneDrive\Documents\Power BI Desktop\Custom Connectors\envs\textS\Lib\site-packages\ensure\main.py:845, in __call__(self, *args, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x00000229868D80E0> does not match annotation type <class 'int'>
